# %% [markdown]
# <a href="https://colab.research.google.com/github/Dipomitagenz/Python-OOPs/blob/main/Copy_of_Python_OOPs_Questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **THEORY QUESTIONS**

# %% [markdown]
# ***1)What is Object-Oriented Programming?***

# %% [markdown]
# Object-oriented programming (OOP) is a programming paradigm that organizes software design around objects, rather than functions and logic. Objects are the fundamental units of OOP, containing both data (attributes) and methods (actions). OOP emphasizes the concept of classes, which act as blueprints for creating objects.

# %% [markdown]
# **2) What is a class in OOP?**

# %% [markdown]
# In Object-Oriented Programming (OOP), a class is a blueprint or template for creating objects. It defines the structure and behavior of a group of objects that share common characteristics and functionalities. Think of a class as a recipe for creating a specific type of object, like a dog or a car.

# %% [markdown]
# **3)What is an object in OOP?**

# %% [markdown]
# In object-oriented programming (OOP), an object is a fundamental unit that combines data (attributes) and actions (methods) to represent a real-world entity or concept. It's essentially an instance of a class, a blueprint that defines the object's structure and behavior.

# %% [markdown]
# **4)What is the difference between abstraction and encapsulation?**

# %% [markdown]
# **Encapsulation**
# is the mechanism of bundling data (attributes) and methods that operate on that data within a single unit (a class). It also involves controlling access to the data, often through access modifiers like private or protected. The primary goal of encapsulation is to protect the integrity of the data and prevent unintended modifications from outside the class.
#
# **Abstraction**
# focuses on hiding complex implementation details and exposing only essential information to the user. It allows programmers to work with objects at a higher level of understanding, without needing to know the intricacies of how they function internally. Abstraction is often achieved through abstract classes and interfaces.

# %% [markdown]
# **5)What are dunder methods in Python?**

# %% [markdown]
# Dunder methods, also known as magic methods, are special methods in Python that begin and end with double underscores (e.g., __init__, __str__, __add__). They are used to implement operator overloading and customize class behavior. These methods are not typically called directly but are invoked by Python when certain operations are performed on objects of the class. For example, __init__ is called when an object is created, __str__ is called when the str() function is used on an object, and __add__ is called when the + operator is used between two objects.
# Dunder methods enable classes to integrate seamlessly with Python's built-in functionalities, allowing for more intuitive and expressive code. They are fundamental to Python's object model and are used extensively in both standard libraries and user-defined classes.

# %% [markdown]
# **6)Explain the concept of inheritance in OOP?**

# %% [markdown]
# Inheritance in Object-Oriented Programming (OOP) is a mechanism where a class (called the derived or child class) can inherit properties and behaviors from another class (the base or parent class). This allows for code reuse and establishes a hierarchical relationship between classes, making it easier to create specialized classes from more general ones.

# %% [markdown]
# **7)What is polymorphism in OOP?**

# %% [markdown]
# In Object-Oriented Programming (OOP), polymorphism, meaning "many forms," allows objects of different classes to be treated as objects of a common superclass, enabling them to respond to the same method call in different ways. This concept promotes code reusability and flexibility, allowing multiple classes to implement the same method with variations.

# %% [markdown]
# **8)How is encapsulation achieved in Python?**

# %% [markdown]
# Encapsulation in Python is achieved by restricting access to attributes and methods, effectively hiding the internal state of an object and preventing unintended modifications. While Python doesn't enforce access modifiers like private, protected, and public in the same way as other languages, it uses naming conventions to indicate the intended level of access.
# Private Attributes:
# Attributes with a double underscore prefix (__attribute) are considered private. Python uses name mangling to make them harder to access directly from outside the class. However, it's still possible, but it signals that it's intended for internal use.
# Protected Attributes:
# Attributes with a single underscore prefix (_attribute) are considered protected. This suggests that they should only be accessed within the class and its subclasses, but it's more of a convention than a strict rule.
# Public Attributes:
# Attributes without any prefix are public and can be accessed from anywhere.
# Encapsulation is often implemented using getter and setter methods to control access to the attributes. This allows for data validation and modification logic to be included when getting or setting the value of an attribute.

# %% [markdown]
# 9)**What is a constructor in Python?**

# %% [markdown]
# A constructor in Python is a special method used to initialize objects of a class. It is automatically called when an object is created. The constructor's primary purpose is to set up the initial state of the object by assigning values to its attributes. In Python, the constructor is named __init__. It always takes self as its first argument, which refers to the instance of the object being created.

# %%
class Dog:
    def __init__(self, name, breed):
        self.name = name
        self.breed = breed

my_dog = Dog("Buddy", "Golden Retriever")
print(my_dog.name)
print(my_dog.breed)
# Out:
# Buddy
# Golden Retriever

# %% [markdown]
# **10)What are class and static methods in Python?**

# %% [markdown]
# Class methods and static methods are special types of methods in Python classes that differ from regular instance methods in how they are called and the arguments they receive.
#
# **Class Methods:**
# They are bound to the class and not the instance of the class.
# They receive the class itself as the first argument, conventionally named cls.
# They can access and modify class-level attributes.
# They are defined using the @classmethod decorator.
# They are called using the class name or an instance of the class.
#
# **Static Methods:**
# They are also bound to the class and not the instance.
# They do not receive any implicit first argument.
# They cannot access or modify class-level or instance-level attributes directly.
# They are defined using the @staticmethod decorator.
# They are called using the class name or an instance of the class.

# %% [markdown]
#  **11)What is method overloading in Python?**

# %% [markdown]
# Method overloading in Python refers to the ability to define multiple methods in a class with the same name but different parameters. However, Python does not support traditional method overloading in the same way as languages like Java or C++. In Python, if you define multiple methods with the same name, the last definition will override any previous definitions.
# To achieve the effect of method overloading in Python, you can use techniques like default arguments or variable-length argument lists (*args and **kwargs). This allows you to create a single method that can handle different numbers or types of arguments.

# %%
class Calculator:
    def add(self, a, b=None, c=None):
        if b is not None and c is not None:
            return a + b + c
        elif b is not None:
            return a + b
        else:
            return a

calc = Calculator()
print(calc.add(5))
print(calc.add(5, 10))
print(calc.add(5, 10, 15))
# Out:
# 5
# 15
# 30

# %% [markdown]
# 12)**What is method overriding in OOP?**

# %% [markdown]
# In Object-Oriented Programming (OOP), method overriding is when a subclass provides a specific implementation for a method that is already defined in its superclass or parent class. This allows the subclass to modify or extend the method's behavior while maintaining the same method signature (name, arguments) as the superclass.
#
# Key aspects of method overriding:
#
# **Inheritance**:
# Method overriding is always tied to inheritance, where a subclass inherits properties and methods from its superclass.
#
# Same Signature:
# The overriding method in the subclass must have the same name, the same number and types of parameters (arguments), and the same return type as the method in the superclass.
# Polymorphism:
# Method overriding is a form of polymorphism, where different classes can respond to the same method call in their own specific ways.
# Runtime Binding:
# The actual method that is executed depends on the object's type at runtime.
# Example:
# Consider an example where there's a class Animal with a makeSound() method. A subclass, Dog, could override the makeSound() method to provide a specific barking sound, while a subclass Cat could override it to provide a meowing sound.

# %%
class Animal:
    def makeSound(self):
        print("Generic animal sound")

class Dog(Animal):
    def makeSound(self):
        print("Woof!")

class Cat(Animal):
    def makeSound(self):
        print("Meow!")

# %% [markdown]
# **13) What is a property decorator in Python?**

# %% [markdown]
# In Python, a property decorator is a built-in feature that allows methods to be accessed like attributes. It provides a way to encapsulate the logic for getting, setting, and deleting an attribute within a class, without requiring explicit getter and setter methods. This mechanism enables controlled access to an object's attributes, allowing for data validation, computation, or other actions to be performed when an attribute is accessed or modified. The @property decorator is used to define the getter method, while @attribute.setter and @attribute.deleter can be used to define the setter and deleter methods, respectively.

# %% [markdown]
# 14)**Why is polymorphism important in OOP?**

# %% [markdown]
# Polymorphism is crucial in OOP because it allows objects of different classes to be treated as objects of a common type, enabling code reusability, flexibility, and maintainability. It promotes a single interface for different functionalities, making the code more adaptable and easier to extend without disrupting existing functionality.
#
# Here's a more detailed explanation:
# Code Reusability:
# Polymorphism allows you to define a single method name that can be used by multiple classes, avoiding the need for creating separate, redundant method names.
# Flexibility:
# It enables objects of different classes to respond to the same method invocation differently, based on their specific implementations.
# Maintainability:
# By using a common interface, you can easily add new subclasses without needing to modify existing methods, making the code more maintainable and easier to extend.
# Enhanced Abstraction:
# Polymorphism allows you to work with objects at a higher level of abstraction, focusing on the interface rather than the specific implementation details.
# Dynamic Dispatch:
# At runtime, the specific method to be executed is determined by the actual object being called, allowing for more dynamic and flexible behavior.

# %% [markdown]
# **15)What is an abstract class in Python?**

# %% [markdown]
# An abstract class in Python is a class that cannot be instantiated directly and serves as a blueprint for other classes. It defines a common interface for a group of related classes, ensuring that subclasses implement specific methods. Abstract classes are created using the abc (Abstract Base Classes) module, and they can contain abstract methods, which are declared but lack implementation in the abstract class.
# To define an abstract class, you inherit from abc.ABC and use the @abc.abstractmethod decorator to mark methods that must be implemented by subclasses. Attempting to instantiate an abstract class or a subclass that hasn't implemented all abstract methods will raise a TypeError.

# %%
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

    @abstractmethod
    def perimeter(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius * self.radius

    def perimeter(self):
        return 2 * 3.14 * self.radius

class Square(Shape):
    def __init__(self, side):
        self.side = side

    def area(self):
        return self.side * self.side

    def perimeter(self):
        return 4 * self.side

# Trying to instantiate the abstract class will raise an error
# shape = Shape() # TypeError: Can't instantiate abstract class Shape with abstract methods area, perimeter

circle = Circle(5)
print(f"Circle area: {circle.area()}")
print(f"Circle perimeter: {circle.perimeter()}")

square = Square(4)
print(f"Square area: {square.area()}")
print(f"Square perimeter: {square.perimeter()}")
# Out:
# Circle area: 78.5
# Circle perimeter: 31.400000000000002
# Square area: 16
# Square perimeter: 16

# %% [markdown]
# **16)What are the advantages of OOP?**

# %% [markdown]
# Object-Oriented Programming (OOP) offers several advantages, including improved code organization through encapsulation, reusability via inheritance, and flexibility through polymorphism. These features lead to modular, maintainable, and scalable software solutions.
# Here's a more detailed look at the benefits:
# 1. Modularity and Organization:
# Encapsulation:
# OOP allows you to bundle data and methods into self-contained units called objects, making them easier to manage and troubleshoot.
# Clear Structure:
# OOP promotes a structured approach to software design, making it easier to understand and maintain.
# Smaller, Manageable Units:
# Complex systems can be broken down into smaller, more manageable objects, enhancing code readability and simplifying development.
# 2. Reusability and Code Efficiency:
# Inheritance:
# OOP allows you to create new classes (child classes) that inherit properties and methods from existing classes (parent classes), promoting code reuse and reducing redundancy.
# Code Recycling:
# You can use the code from a master class and only change the required features for your child code, further enhancing efficiency.
# Reduced Duplication:
# Inheritance eliminates the need for code duplication, saving time and effort in development.
# 3. Flexibility and Adaptability:
# Polymorphism:
# OOP enables objects of different classes to be treated in a generic way, making the code more adaptable and flexible.
# Easy Upgrades and Scalability:
# OOP systems can be easily upgraded and scaled to handle larger projects, thanks to their modular structure and adaptability.
# Flexibility in Project Design:
# OOP provides better flexibility when it comes to designing projects, allowing for more creative solutions.
# 4. Enhanced Productivity and Maintainability:
# Increased Productivity:
# OOP promotes efficient development practices, leading to increased productivity for developers.
# Easier Maintenance:
# OOP makes it easier to maintain and update existing code, as changes can be made to individual objects without affecting unrelated parts of the system.
# Improved Troubleshooting:
# OOP facilitates quick issue resolution by isolating problems within specific objects, making debugging more efficient.
# 5. Security and Data Integrity:
# Encapsulation and Abstraction:
# OOP provides mechanisms to protect data and control access to it, enhancing the security of the code and the software.
# Reduced Data Redundancy:
# Encapsulating data within objects and exposing only essential interfaces minimizes redundancy, further improving security.

# %% [markdown]
# **17)What is the difference between a class variable and an instance variable?**

# %% [markdown]
# The key difference between class and instance variables lies in their scope and how they are accessed. Class variables are shared among all instances of a class, while instance variables are unique to each instance.
#
# **Class Variables**:
# Defined within a class but outside of any methods.
# Shared by all instances of the class.
# Accessed using the class name or an instance of the class.
# Changes made to a class variable affect all instances.
#
# **Instance Variables**:
# Defined within the __init__ method or other instance methods using self.
# Unique to each instance of the class.
# Accessed using the instance name.
# Changes made to an instance variable only affect that specific instance.

# %%
class MyClass:
    class_variable = "Shared by all"

    def __init__(self, instance_variable):
        self.instance_variable = instance_variable

# Creating instances
obj1 = MyClass("Instance 1")
obj2 = MyClass("Instance 2")

# Accessing class variable
print(MyClass.class_variable)  # Output: Shared by all
print(obj1.class_variable)   # Output: Shared by all
print(obj2.class_variable)   # Output: Shared by all

# Accessing instance variables
print(obj1.instance_variable)  # Output: Instance 1
print(obj2.instance_variable)  # Output: Instance 2

# Modifying class variable
MyClass.class_variable = "Modified class variable"
print(obj1.class_variable) # Output: Modified class variable
print(obj2.class_variable) # Output: Modified class variable

# Modifying instance variable
obj1.instance_variable = "Modified instance 1"
print(obj1.instance_variable)  # Output: Modified instance 1
print(obj2.instance_variable)  # Output: Instance 2
# Out:
# Shared by all
# Shared by all
# Shared by all
# Instance 1
# Instance 2
# Modified class variable
# Modified class variable
# Modified instance 1
# Instance 2

# %% [markdown]
# **18)What is multiple inheritance in Python?**

# %% [markdown]
# Multiple inheritance in Python is a feature that allows a class to inherit attributes and methods from more than one parent class. This enables a class to combine functionalities from different sources, creating a more versatile and specialized class. When a class inherits from multiple parent classes, it gains access to all the attributes and methods of those parent classes. If there are naming conflicts (i.e., the same method name exists in multiple parent classes), Python resolves them using Method Resolution Order (MRO), which defines the order in which parent classes are searched for a method.

# %%
class Base1:
    def __init__(self):
        self.base1_attribute = "Base 1"
    def base_method(self):
        print("Method from Base 1")

class Base2:
    def __init__(self):
        self.base2_attribute = "Base 2"
    def base_method(self):
        print("Method from Base 2")

class Derived(Base1, Base2):
    def __init__(self):
        Base1.__init__(self)
        Base2.__init__(self)
        self.derived_attribute = "Derived"
    def derived_method(self):
        print("Method from Derived")

# Creating an object of the Derived class
obj = Derived()

# Accessing attributes from base classes
print(obj.base1_attribute)
print(obj.base2_attribute)
print(obj.derived_attribute)

# Calling methods from base classes
obj.base_method()

# Calling method from derived class
obj.derived_method()
# Out:
# Base 1
# Base 2
# Derived
# Method from Base 1
# Method from Derived

# %% [markdown]
# **19)Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python?**

# %% [markdown]
# In Python, __str__ and __repr__ are special methods used to define how objects are represented as strings. They serve different purposes and are used in different contexts.
# __str__(self): This method returns a human-readable string representation of an object. It is intended for the end-user and is called by the built-in str() function and the print() function. If __str__ is not defined, Python will fall back to using __repr__.
# __repr__(self): This method returns an unambiguous string representation of an object. It is intended for developers and debugging purposes. It should ideally return a string that can be used to recreate the object. It is called by the built-in repr() function.
# In essence, __str__ aims for readability, while __repr__ aims for unambiguity and completeness. It's good practice to implement both methods in your classes to provide clear and useful string representations for different situations. If only one of these methods is defined, and __str__ is absent, __repr__ will be used for both str() and repr().

# %% [markdown]
# **20)What is the significance of the ‘super()’ function in Python?**

# %% [markdown]
# The super() function in Python is used to call methods from a parent class within a subclass. This is particularly useful in scenarios involving inheritance, where a subclass extends or modifies the behavior of its parent class. The primary significance of super() lies in its ability to promote code reusability, maintainability, and flexibility in object-oriented programming.
# When a subclass overrides a method of its parent class, it can still invoke the original method from the parent class using super(). This allows the subclass to extend the functionality of the parent class method without completely replacing it. Moreover, super() simplifies code maintenance by eliminating the need to explicitly name the parent class when calling its methods. This makes the code more adaptable to changes in the class hierarchy.
# In multiple inheritance scenarios, super() plays a crucial role in ensuring that methods from different parent classes are called in the correct order, following the method resolution order (MRO). This prevents issues like the diamond problem, where a subclass inherits from two classes that have a common ancestor.

# %%
class Animal:
    def __init__(self, name):
        self.name = name

    def speak(self):
        print("Generic animal sound")

class Dog(Animal):
    def __init__(self, name, breed):
        super().__init__(name)
        self.breed = breed

    def speak(self):
        super().speak()
        print("Woof!")

my_dog = Dog("Buddy", "Golden Retriever")
my_dog.speak()
# Expected output:
# Generic animal sound
# Woof!
# Out:
# Generic animal sound
# Woof!

# %% [markdown]
# 21)**What is the significance of the __del__ method in Python?**

# %% [markdown]
# The del statement in Python is used to delete objects, which can include variables, list items, dictionary entries, or slices of a list. It removes the name or binding from the specified object, and if that object has no other references, it is cleared from memory. The primary purposes of del are to remove elements from mutable data structures and to unbind variables. It is not a function but a statement because it operates on the binding or variable itself, not the value it references.

# %%
my_list = [1, 2, 3, 4]
del my_list[0]  # Removes the element at index 0
print(my_list)  # Output: [2, 3, 4]

my_dict = {"a": 1, "b": 2}
del my_dict["a"]  # Removes the key "a" and its value
print(my_dict)  # Output: {'b': 2}

x = 10
del x  # Unbinds the variable x
# print(x)  # This would raise a NameError because x is no longer define
# Out:
# [2, 3, 4]
# {'b': 2}

# %% [markdown]
# **22)What is the difference between @staticmethod and @classmethod in Python?**

# %% [markdown]
# The key differences between @staticmethod and @classmethod in Python involve their interaction with the class and its instances:
#
# @**staticmethod**:
# It is a function defined within a class but does not receive the class or instance as an implicit first argument.
# It cannot access or modify class-specific or instance-specific attributes.
# It is essentially a regular function that is logically grouped within a class.
# It is used for utility functions that do not depend on the class or instance state.
#
# @**classmethod**:
# It receives the class itself as an implicit first argument, conventionally named cls.
# It can access and modify class-level attributes (static variables).
# It cannot directly access instance-specific attributes.
# It is often used for factory methods (alternative constructors) or operations that involve the class as a whole.

# %%
class MyClass:
    class_var = "I am a class variable"

    def __init__(self, instance_var):
        self.instance_var = instance_var

    @staticmethod
    def static_method(x, y):
        # Can't access self or cls
        return x + y

    @classmethod
    def class_method(cls, value):
        # Can access cls
        print(cls.class_var)
        return cls(value)

# Usage
print(MyClass.static_method(5, 3))

obj = MyClass.class_method("hello")
print(obj.instance_var)
# Out:
# 8
# I am a class variable
# hello

# %% [markdown]
# 23)**How does polymorphism work in Python with inheritance?**

# %% [markdown]
# Polymorphism in Python, specifically when used with inheritance, allows objects of different classes to respond to the same method call in a way that is specific to their class. This is achieved through method overriding. When a subclass inherits from a parent class, it can redefine the methods of the parent class to fit its own needs.
# Consider a scenario with a base class Shape that has a method area(). Subclasses like Circle and Square can inherit from Shape and override the area() method to calculate the area specific to their shapes. When area() is called on an object, the correct version of the method, as defined in the object's class, is executed. This ensures that even though the same method name is used, the behavior is tailored to the specific object type, demonstrating polymorphism.

# %%
class Shape:
    def area(self):
        return "Area of shape is undefined"

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius * self.radius

class Square(Shape):
    def __init__(self, side):
        self.side = side

    def area(self):
        return self.side * self.side

shapes = [Circle(5), Square(4)]
for shape in shapes:
    print(shape.area())
# Out:
# 78.5
# 16

# %% [markdown]
# **24)What is method chaining in Python OOP?**

# %% [markdown]
# Method chaining in Python is a programming technique used in object-oriented programming that allows multiple methods to be called sequentially on the same object in a single line of code. It enhances code readability and conciseness by eliminating the need for intermediate variables. To implement method chaining, each method in the class must return the object itself (typically using return self). This allows the subsequent method to be called directly on the result of the previous method.
# For example, consider a class Car with methods like turn_on, drive, brake, and turn_off. Without method chaining, these methods would be called separately.

# %%
class Car:
    def turn_on(self):
        print("Engine started")
        return self

    def drive(self):
        print("Car is moving")
        return self

    def brake(self):
        print("Brakes applied")
        return self

    def turn_off(self):
        print("Engine stopped")
        return self

my_car = Car()
my_car.turn_on()
my_car.drive()
my_car.brake()
my_car.turn_off()
# Out:
# Engine started
# Car is moving
# Brakes applied
# Engine stopped

# %% [markdown]
# **25)What is the purpose of the __call__ method in Python?**

# %% [markdown]
# The __call__ method in Python enables instances of a class to be called as if they were functions. When a class defines the __call__ method, it makes its instances "callable." This means you can use parentheses () on the instance, just like you would with a regular function. The __call__ method can take arguments, similar to a function, and perform operations using these arguments and the object's internal state.

# %%
class Example:
    def __init__(self, name):
        self.name = name

    def __call__(self, greeting):
        return f"{greeting}, {self.name}!"

obj = Example("Alice")
message = obj("Hello")
print(message)
# Out:
# Hello, Alice!

# %% [markdown]
# **Practical questions**
